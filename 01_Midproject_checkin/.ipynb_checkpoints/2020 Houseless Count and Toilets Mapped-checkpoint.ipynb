# %% [markdown]
# ## 2020 Houseless Count and Toilets Mapped

# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt

# %%
toilets = gpd.read_file('MiscData/toilets.geojson').to_crs(epsg=3857)

# %%
toilets.sample(10)
# Out:
#                                                   name  \
# 59                 South Hill Street & West 5th Street
# 76              Beacon Avenue (Between 7th and 8th St)
# 113                 South Alvarado Street and Maryland
# 145                    De Soto Avenue & Bassett Street
# 117                     Paxton Street & Bradley Avenue
# 181                                    Sunset & LaBrea
# 114                       Woodley Ave and Burbank Blvd
# 21   Orcutt Ranch Horticultural Center & Community ...
# 274                      SW corner of Hampton & Sunset
# 236                 8800 S. Hoover (Algin Sutton Park)
#
#                               type                 geometry
# 59       LAHSA Handwashing Station  POINT (-118.252 34.049)
# 76       LAHSA Handwashing Station  POINT (-118.273 34.054)
# 113      LAHSA Handwashing Station  POINT (-118.273 34.062)
# 145      LAHSA Handwashing Station  POINT (-118.588 34.196)
# 117      LAHSA Handwashing Station  POINT (-118.425 34.275)
# 181      LAHSA Handwashing Station  POINT (-118.344 34.098)
# 114      LAHSA Handwashing Station  POINT (-118.476 34.172)
# 21                        LA Parks  POINT (-118.640 34.218)
# 274  Community Handwashing Station  POINT (-118.475 33.995)
# 236      LAHSA Handwashing Station  POINT (-118.287 33.957)

# %%
counts = gpd.read_file('MiscData/2020countbytract.geojson')

# %%
counts.head()
# Out:
#    Count                                           geometry
# 0   1463  MULTIPOLYGON (((-118.30229 34.25870, -118.3009...
# 1    671  MULTIPOLYGON (((-118.30334 34.27371, -118.3033...
# 2   1445                                               None
# 3   1703  MULTIPOLYGON (((-118.28593 34.25227, -118.2859...
# 4   1578  MULTIPOLYGON (((-118.27822 34.25068, -118.2782...

# %%
# Plotting both toilets and counts on the same map

f, ax = plt.subplots(figsize=(20,20))

toilets.plot('type', ax=ax, marker='o', markersize=20, legend=True)

counts.plot('Count', ax=ax, cmap='plasma', legend=True, legend_kwds={'orientation': 'vertical'}, alpha=0.2, label='Count')

ax.set_xlim([-118.721783, -118.08]) 
ax.set_ylim([33.68, 34.4])

ctx.add_basemap(ax,crs='EPSG:4326', source=ctx.providers.Stamen.TonerLite)

plt.show()
