# %% [markdown]
# # 2020 Homeless Count Data by Census Tract
# ### Source: Economic Roundtable https://economicrt.org/publication/los-angeles-county-homeless-count-data-library/
#
# This data was sent to me by Tiffany when I was asking for houseless count data by census tract. Thanks Tiffany!

# %%
#Importing the excel spreadsheet as a dataframe

import pandas as pd

df = pd.read_excel('2020-Street-Count-Results-by-Census-Tract-trimmed.xlsx')

# %%
# Taking a look at which are the relevant columns. Looks like 'FID_LA_Cou' is the count data
df.head()
# Out:
#    FID_LA_Cou  STATEFP10  COUNTYFP10  TRACTCE10     GEOID10  Non-CoC Flag  \
# 0        1463          6          37     101110  6037101110             1
# 1         671          6          37     101122  6037101122             1
# 2        1445          6          37     101210  6037101210             1
# 3        1703          6          37     101220  6037101220             1
# 4        1578          6          37     101300  6037101300             1
#
#                 Non-CoC Place   NAME10            NAMELSAD10  \
# 0  Great LA Continuum of Care  1011.10  Census Tract 1011.10
# 1  Great LA Continuum of Care  1011.22  Census Tract 1011.22
# 2  Great LA Continuum of Care  1012.10  Census Tract 1012.10
# 3  Great LA Continuum of Care  1012.20  Census Tract 1012.20
# 4  Great LA Continuum of Care  1013.00     Census Tract 1013
#
#                CT_NAME  ... FUNCSTAT10  ALAND10  AWATER10  INTPTLAT10  \
# 0  Tujunga Canyon Blvd  ...          S  1142405         0   34.259474
# 1                  NaN  ...          S  2644043         0   34.267721
# 2  Little Landers Park  ...          S   650691         0   34.252972
# 3    Haines Canyon Ave  ...          S   698967         0   34.251609
# 4      Mt. Glesson Ave  ...          S  2580401         0   34.248778
#
#    INTPTLON10  FID_Servic             SPA_NAME SPA_2012  LACityCD12  \
# 0 -118.292987           1  SPA 2: San Fernando        2         7.0
# 1 -118.290147           1  SPA 2: San Fernando        2         7.0
# 2 -118.290731           1  SPA 2: San Fernando        2         7.0
# 3 -118.281632           1  SPA 2: San Fernando        2         7.0
# 4 -118.270999           1  SPA 2: San Fernando        2         7.0
#
#    LA_CoSupDist11
# 0               5
# 1               5
# 2               5
# 3               5
# 4               5
#
# [5 rows x 21 columns]

# %%
# We've got lat long so let's turn this into a GDF
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344 entries, 0 to 2343
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   FID_LA_Cou      2344 non-null   int64
#  1   STATEFP10       2344 non-null   int64
#  2   COUNTYFP10      2344 non-null   int64
#  3   TRACTCE10       2344 non-null   int64
#  4   GEOID10         2344 non-null   int64
#  5   Non-CoC Flag    2344 non-null   int64
#  6   Non-CoC Place   2344 non-null   object
#  7   NAME10          2344 non-null   float64
#  8   NAMELSAD10      2344 non-null   object
#  9   CT_NAME         1695 non-null   object
#  10  MTFCC10         2344 non-null   object
#  11  FUNCSTAT10      2344 non-null   object
#  12  ALAND10         2344 non-null   int64
#  13  AWATER10        2344 non-null   int64
#  14  INTPTLAT10      2344 non-null   float64
#  15  INTPTLON10      2344 non-null   float64
#  16  FID_Servic      2344 non-null   int64
#  17  SPA_NAME        2344 non-null   object
#  18  SPA_2012        2344 non-null   int64
#  19  LACityCD12      999 non-null    float64
#  20  LA_CoSupDist11  2344 non-null   int64
# dtypes: float64(4), int64(11), object(6)
# memory usage: 384.7+ KB

# %%
# Converting to GDF with the appropriate columns as lat and long
import geopandas as gpd
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.INTPTLON10, df.INTPTLAT10))

# %%
# Quick look, seems to have worked
gdf
# Out:
#       FID_LA_Cou  STATEFP10  COUNTYFP10  TRACTCE10     GEOID10  Non-CoC Flag  \
# 0           1463          6          37     101110  6037101110             1
# 1            671          6          37     101122  6037101122             1
# 2           1445          6          37     101210  6037101210             1
# 3           1703          6          37     101220  6037101220             1
# 4           1578          6          37     101300  6037101300             1
# ...          ...        ...         ...        ...         ...           ...
# 2339        2046          6          37     577602  6037577602             2
# 2340        2044          6          37     577603  6037577603             2
# 2341        2159          6          37     577604  6037577604             2
# 2342        1695          6          37     980018  6037980018             2
# 2343        1691          6          37     980033  6037980033             2
#
#                    Non-CoC Place   NAME10            NAMELSAD10  \
# 0     Great LA Continuum of Care  1011.10  Census Tract 1011.10
# 1     Great LA Continuum of Care  1011.22  Census Tract 1011.22
# 2     Great LA Continuum of Care  1012.10  Census Tract 1012.10
# 3     Great LA Continuum of Care  1012.20  Census Tract 1012.20
# 4     Great LA Continuum of Care  1013.00     Census Tract 1013
# ...                          ...      ...                   ...
# 2339         Long Beach city, CA  5776.02  Census Tract 5776.02
# 2340         Long Beach city, CA  5776.03  Census Tract 5776.03
# 2341         Long Beach city, CA  5776.04  Census Tract 5776.04
# 2342         Long Beach city, CA  9800.18  Census Tract 9800.18
# 2343         Long Beach city, CA  9800.33  Census Tract 9800.33
#
#                         CT_NAME  ...   ALAND10  AWATER10  INTPTLAT10  \
# 0           Tujunga Canyon Blvd  ...   1142405         0   34.259474
# 1                           NaN  ...   2644043         0   34.267721
# 2           Little Landers Park  ...    650691         0   34.252972
# 3             Haines Canyon Ave  ...    698967         0   34.251609
# 4               Mt. Glesson Ave  ...   2580401         0   34.248778
# ...                         ...  ...       ...       ...         ...
# 2339  Bixby Village Golf Course  ...   1324998     69272   33.770058
# 2340   Marine Stadium Acueducto  ...   2682520    298384   33.769113
# 2341                        NaN  ...    853432    645395   33.755750
# 2342                        NaN  ...   7372384     21307   33.815252
# 2343                        NaN  ...  12678805  16041382   33.744315
#
#       INTPTLON10  FID_Servic             SPA_NAME  SPA_2012 LACityCD12  \
# 0    -118.292987           1  SPA 2: San Fernando         2        7.0
# 1    -118.290147           1  SPA 2: San Fernando         2        7.0
# 2    -118.290731           1  SPA 2: San Fernando         2        7.0
# 3    -118.281632           1  SPA 2: San Fernando         2        7.0
# 4    -118.270999           1  SPA 2: San Fernando         2        7.0
# ...          ...         ...                  ...       ...        ...
# 2339 -118.112671           7     SPA 8: South Bay         8        NaN
# 2340 -118.127319           7     SPA 8: South Bay         8        NaN
# 2341 -118.110085           7     SPA 8: South Bay         8        NaN
# 2342 -118.153909           7     SPA 8: South Bay         8        NaN
# 2343 -118.220310           7     SPA 8: South Bay         8        NaN
#
#       LA_CoSupDist11                     geometry
# 0                  5  POINT (-118.29299 34.25947)
# 1                  5  POINT (-118.29015 34.26772)
# 2                  5  POINT (-118.29073 34.25297)
# 3                  5  POINT (-118.28163 34.25161)
# 4                  5  POINT (-118.27100 34.24878)
# ...              ...                          ...
# 2339               4  POINT (-118.11267 33.77006)
# 2340               4  POINT (-118.12732 33.76911)
# 2341               4  POINT (-118.11009 33.75575)
# 2342               4  POINT (-118.15391 33.81525)
# 2343               4  POINT (-118.22031 33.74432)
#
# [2344 rows x 22 columns]

# %%
# Quick plot to make sure it looks like LA County, sure enough it does
gdf.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bringing in tract polygon data by using 2020 ACS total pop table's geometry column

# %%
# Because the houseless count data is only point data, but has the census tracts, I wanted to bring in tract data
# Census API gave me a "Max retries exceeded" error, so just downloaded the JSON
acs_gdf = gpd.read_file('acs2020_5yr_B01003_14000US06037463000.geojson')
acs_gdf
# Out:
#                    geoid                                   name   B01003001  \
# 0           05000US06037                 Los Angeles County, CA  10040682.0
# 1     14000US06037101110  Census Tract 1011.10, Los Angeles, CA      3923.0
# 2     14000US06037101122  Census Tract 1011.22, Los Angeles, CA      4119.0
# 3     14000US06037101220  Census Tract 1012.20, Los Angeles, CA      3775.0
# 4     14000US06037101221  Census Tract 1012.21, Los Angeles, CA      3787.0
# ...                  ...                                    ...         ...
# 2494  14000US06037980038  Census Tract 9800.38, Los Angeles, CA         0.0
# 2495  14000US06037980039  Census Tract 9800.39, Los Angeles, CA         0.0
# 2496  14000US06037990100     Census Tract 9901, Los Angeles, CA         0.0
# 2497  14000US06037990200     Census Tract 9902, Los Angeles, CA         0.0
# 2498  14000US06037990300     Census Tract 9903, Los Angeles, CA         0.0
#
#       B01003001, Error                                           geometry
# 0                  0.0  MULTIPOLYGON (((-118.70339 34.16859, -118.7033...
# 1                460.0  MULTIPOLYGON (((-118.30229 34.25870, -118.3009...
# 2                858.0  MULTIPOLYGON (((-118.30334 34.27371, -118.3033...
# 3                474.0  MULTIPOLYGON (((-118.28593 34.25227, -118.2859...
# 4                651.0  MULTIPOLYGON (((-118.29945 34.25598, -118.2979...
# ...                ...                                                ...
# 2494              13.0  MULTIPOLYGON (((-118.39099 34.00167, -118.3909...
# 2495              13.0  MULTIPOLYGON (((-118.36215 34.13903, -118.3612...
# 2496              13.0  MULTIPOLYGON (((-118.95114 33.99643, -118.9505...
# 2497              13.0  MULTIPOLYGON (((-118.63598 34.03255, -118.6325...
# 2498              13.0  MULTIPOLYGON (((-118.47656 33.75038, -118.4661...
#
# [2499 rows x 5 columns]

# %%
# Prepping our tract column for a merge making text similar format as our homeless count data

# Dropping irrelevant columns and rows
acs_gdf.drop(columns=['geoid', 'B01003001', 'B01003001, Error'], inplace=True)
acs_gdf.drop([0], inplace=True)

# Making tract text similar format as our homeless count data
acs_gdf['name'] = acs_gdf['name'].str.replace(", Los Angeles, CA","")

# Setting index on tract for both gdf's
acs_gdf.set_index(['name'], inplace=True)
gdf.set_index(['NAMELSAD10'], inplace=True)

# Renaming ACS geometry column
acs_gdf.rename(columns={'geometry':'geometry_tract'}, inplace=True)

# %%
# Joining 

joinedGdf = gdf.join(acs_gdf, how='left')
joinedGdf.head()
# Out:
#                       FID_LA_Cou  STATEFP10  COUNTYFP10  TRACTCE10  \
# NAMELSAD10
# Census Tract 1011.10        1463          6          37     101110
# Census Tract 1011.22         671          6          37     101122
# Census Tract 1012.10        1445          6          37     101210
# Census Tract 1012.20        1703          6          37     101220
# Census Tract 1013           1578          6          37     101300
#
#                          GEOID10  Non-CoC Flag               Non-CoC Place  \
# NAMELSAD10
# Census Tract 1011.10  6037101110             1  Great LA Continuum of Care
# Census Tract 1011.22  6037101122             1  Great LA Continuum of Care
# Census Tract 1012.10  6037101210             1  Great LA Continuum of Care
# Census Tract 1012.20  6037101220             1  Great LA Continuum of Care
# Census Tract 1013     6037101300             1  Great LA Continuum of Care
#
#                        NAME10              CT_NAME MTFCC10  ... AWATER10  \
# NAMELSAD10                                                  ...
# Census Tract 1011.10  1011.10  Tujunga Canyon Blvd   G5020  ...        0
# Census Tract 1011.22  1011.22                  NaN   G5020  ...        0
# Census Tract 1012.10  1012.10  Little Landers Park   G5020  ...        0
# Census Tract 1012.20  1012.20    Haines Canyon Ave   G5020  ...        0
# Census Tract 1013     1013.00      Mt. Glesson Ave   G5020  ...        0
#
#                       INTPTLAT10  INTPTLON10  FID_Servic             SPA_NAME  \
# NAMELSAD10
# Census Tract 1011.10   34.259474 -118.292987           1  SPA 2: San Fernando
# Census Tract 1011.22   34.267721 -118.290147           1  SPA 2: San Fernando
# Census Tract 1012.10   34.252972 -118.290731           1  SPA 2: San Fernando
# Census Tract 1012.20   34.251609 -118.281632           1  SPA 2: San Fernando
# Census Tract 1013      34.248778 -118.270999           1  SPA 2: San Fernando
#
#                       SPA_2012 LACityCD12  LA_CoSupDist11  \
# NAMELSAD10
# Census Tract 1011.10         2        7.0               5
# Census Tract 1011.22         2        7.0               5
# Census Tract 1012.10         2        7.0               5
# Census Tract 1012.20         2        7.0               5
# Census Tract 1013            2        7.0               5
#
#                                          geometry  \
# NAMELSAD10
# Census Tract 1011.10  POINT (-118.29299 34.25947)
# Census Tract 1011.22  POINT (-118.29015 34.26772)
# Census Tract 1012.10  POINT (-118.29073 34.25297)
# Census Tract 1012.20  POINT (-118.28163 34.25161)
# Census Tract 1013     POINT (-118.27100 34.24878)
#
#                                                          geometry_tract
# NAMELSAD10
# Census Tract 1011.10  MULTIPOLYGON (((-118.30229 34.25870, -118.3009...
# Census Tract 1011.22  MULTIPOLYGON (((-118.30334 34.27371, -118.3033...
# Census Tract 1012.10                                               None
# Census Tract 1012.20  MULTIPOLYGON (((-118.28593 34.25227, -118.2859...
# Census Tract 1013     MULTIPOLYGON (((-118.27822 34.25068, -118.2782...
#
# [5 rows x 22 columns]

# %%
# Resetting the index
joinedGdf.reset_index(inplace=True)

# %%
# Trimming the GDF for mapping
countGdf = joinedGdf[['FID_LA_Cou', 'geometry_tract']]
countGdf.rename(columns={'FID_LA_Cou':'Count', 'geometry_tract':'geometry'}, inplace=True)
# Out:
# /var/folders/kk/wgrg_3tx379d6v98r_2sfh5c0000gn/T/ipykernel_2765/3259570990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countGdf.rename(columns={'FID_LA_Cou':'Count', 'geometry_tract':'geometry'}, inplace=True)

# %%
# Converting to GDF
countGdf = gpd.GeoDataFrame(countGdf)

# %%
# Quick plot to check that the choropleth works
countGdf.plot(column='Count')
# Out:
# <AxesSubplot:>

# %%
# Plotting with matplotlib

import matplotlib.pyplot as plt 

# create a matplotlib figure and axis object
fig, ax = plt.subplots(1,1,figsize=(20,10))

countGdf.plot('Count', ax=ax, cmap='plasma', legend=True, 
               legend_kwds={'orientation': 'horizontal'})

ax.set_xlim=([-118.721783, -117.201676])
ax.set_ylim=([33.701292, 34.176390])
ax.set_facecolor('k')

# %%
# Writing GDF as a json for exporting
import fiona
countGdf.to_file("2020countbytract.geojson", driver='GeoJSON')
# Out:
# /Users/kevin/opt/anaconda3/envs/uds/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
