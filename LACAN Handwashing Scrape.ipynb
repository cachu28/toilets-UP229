# %% [markdown]
# # Scraping the LACAN Google Map Layer

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.google.com/maps/d/u/0/viewer?mid=1ak8NcsKDwokcV0T9j0eQALz7rIHNWzwq&hl=en&ll=34.06844279585848%2C-118.27066246237175&z=10'
r = requests.get(url)

soup = BeautifulSoup(r.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebSite">
#  <head>
#   <title itemprop="name">
#    LA CAN's Handwashing Stations Map - Google My Maps
#   </title>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=0,width=device-width" name="viewport"/>
#   <meta content="Email updates and additions to handwashing@skidrowpower.com - please include:
# - location (use the marker's name if updating)
# - a status description
# - add a picture or video if you can
# Thanks!" itemprop="description" name="description"/>
#   <meta content="https://www.google.com/maps/d/viewer?mid=1ak8NcsKDwokcV0T9j0eQALz7rIHNWzwq&amp;hl=en" itemprop="url"/>
#   <meta content="https://www.google.com/maps/d/thumbnail?mid=1ak8NcsKDwokcV0T9j0eQALz7rIHNWzwq&amp;hl=en" itemprop="image"/>
#   <meta content="website" property="og:type"/>
# ...
